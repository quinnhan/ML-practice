# %% [markdown]
# # Machine Learning
#
# ## Step 1: EDA
#
# ### 1D

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
df = pd.read_csv('ds_salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
# No null values, data types look ok so far
df.duplicated().sum()
# Out:
# 1171

# %% [markdown]
# This dataset has 30% duplication because there is no primary key feature in this dataset. I am not going to drop duplicated records.

# %%
df.hist( figsize = (16,6))
# Out:
# array([[<AxesSubplot:title={'center':'work_year'}>,
#         <AxesSubplot:title={'center':'salary'}>],
#        [<AxesSubplot:title={'center':'salary_in_usd'}>,
#         <AxesSubplot:title={'center':'remote_ratio'}>]], dtype=object)

# %%
df['salary'].describe()
# Out:
# count    3.755000e+03
# mean     1.906956e+05
# std      6.716765e+05
# min      6.000000e+03
# 25%      1.000000e+05
# 50%      1.380000e+05
# 75%      1.800000e+05
# max      3.040000e+07
# Name: salary, dtype: float64

# %%
df[df['salary'] == df['salary'].max()]
# Out:
#       work_year experience_level employment_type       job_title    salary  \
# 3669       2021               MI              FT  Data Scientist  30400000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3669             CLP          40038                 CL           100
#
#      company_location company_size
# 3669               CL            L

# %%
df.drop(['salary', 'salary_currency'], axis = 1, inplace = True)

# %%
cl = df.groupby('company_location')['salary_in_usd'].count()

# %%
cl
# Out:
# company_location
# AE       3
# AL       1
# AM       1
# AR       3
# AS       3
#       ...
# TH       3
# TR       5
# UA       4
# US    3040
# VN       1
# Name: salary_in_usd, Length: 72, dtype: int64

# %%
cl.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='company_location'>

# %% [markdown]
# This is an example of imbalance feature. There are few ways to tackle this problem:
# 1. Not dealing with it: I can choose to just examine US and CA DS job market since the two countries have similar standard of living
# 2. Sampling them based on the distribution
# 3. Make separate model for each category
#
# I am choosing option 1 because this dataset is static

# %%
df_US = df[df['company_location'].isin(['US','CA'])]
df_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3127 entries, 1 to 3753
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3127 non-null   int64
#  1   experience_level    3127 non-null   object
#  2   employment_type     3127 non-null   object
#  3   job_title           3127 non-null   object
#  4   salary_in_usd       3127 non-null   int64
#  5   employee_residence  3127 non-null   object
#  6   remote_ratio        3127 non-null   int64
#  7   company_location    3127 non-null   object
#  8   company_size        3127 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 244.3+ KB

# %%
cat_col = list(df_US.columns[df_US.dtypes == 'object'])
num_col = list(df_US.columns[df_US.dtypes != 'object'])
for col in cat_col:
    plt.figure(figsize=(10, 6))
    df_US[col].value_counts().plot(kind='bar')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.title('Distribution of ' + col)
    plt.show()

# %% [markdown]
# 1. Same with company location, full-timers dominant the dataset.
# 2. I am going to only examine FT. I will create a feature indicates whether the job and employee are in the same location, then drop both columns: 'company_location' and 'employee location'
# 3. Job titles have many values and I will attempt to use KNN to put these title in 4 or 5 cluster.

# %%
df_US = df_US[df_US['employment_type'] == 'FT']

# %%
df_US['employee_at_job_location'] = (df_US['employee_residence']== df_US['company_location']).astype(int)
df_US.drop(['employee_residence','company_location','employment_type'],axis = 1,inplace=True)
df_US.head()
# Out:
#    work_year experience_level          job_title  salary_in_usd  remote_ratio  \
# 3       2023               SE     Data Scientist         175000           100
# 4       2023               SE     Data Scientist         120000           100
# 5       2023               SE  Applied Scientist         222200             0
# 6       2023               SE  Applied Scientist         136000             0
# 7       2023               SE     Data Scientist         219000             0
#
#   company_size  employee_at_job_location
# 3            M                         1
# 4            M                         1
# 5            L                         1
# 6            L                         1
# 7            M                         1

# %%
cat_col = list(df_US.columns[df_US.dtypes == 'object'])
num_col = list(df_US.columns[df_US.dtypes != 'object'])

# %%
from kmodes.kmodes import KModes

# Initialize KModes with 3 clusters
km = KModes(n_clusters=3, init='Huang', n_init=5, verbose=1)

# Fit the model
clusters = km.fit_predict(df_US[['job_title']])

# Assign the cluster labels back to the DataFrame
df_US['job_title_cluster'] = clusters

df_US.head()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 1274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 964.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 1274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 1274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 964.0
# Best run was number 2
#    work_year experience_level          job_title  salary_in_usd  remote_ratio  \
# 3       2023               SE     Data Scientist         175000           100
# 4       2023               SE     Data Scientist         120000           100
# 5       2023               SE  Applied Scientist         222200             0
# 6       2023               SE  Applied Scientist         136000             0
# 7       2023               SE     Data Scientist         219000             0
#
#   company_size  employee_at_job_location  job_title_cluster
# 3            M                         1                  0
# 4            M                         1                  0
# 5            L                         1                  0
# 6            L                         1                  0
# 7            M                         1                  0

# %% [markdown]
# ### 2D

# %%
# Create Pair Plot 
sns.pairplot(df_US)

# %% [markdown]
# There is no dependent on any two features

# %%
for col in cat_col:
    for col1 in cat_col:
        if col == col1: 
            break
        else:
            cross_tab = pd.crosstab(df_US[col], df_US[col1], margins=True)
            print(cross_tab)
# Out:
# experience_level                    EN   EX   MI    SE   All
# job_title
# AI Developer                         0    0    1     1     2
# AI Scientist                         2    1    3     0     6
# Analytics Engineer                   1    8    8    75    92
# Applied Data Scientist               0    0    2     2     4
# Applied Machine Learning Engineer    0    0    1     0     1
# ...                                ...  ...  ...   ...   ...
# Product Data Analyst                 1    0    1     0     2
# Research Engineer                    8    0    5    18    31
# Research Scientist                   6    0   14    43    63
# Staff Data Analyst                   0    1    0     0     1
# All                                182  101  506  2320  3109
#
# [73 rows x 5 columns]
# experience_level   EN   EX   MI    SE   All
# company_size
# L                  43    6   63   164   276
# M                 124   91  431  2138  2784
# S                  15    4   12    18    49
# All               182  101  506  2320  3109
# job_title     AI Developer  AI Scientist  Analytics Engineer  \
# company_size
# L                        0             2                   1
# M                        1             3                  90
# S                        1             1                   1
# All                      2             6                  92
#
# job_title     Applied Data Scientist  Applied Machine Learning Engineer  \
# company_size
# L                                  4                                  0
# M                                  0                                  1
# S                                  0                                  0
# All                                4                                  1
#
# job_title     Applied Machine Learning Scientist  Applied Scientist  \
# company_size
# L                                              4                 30
# M                                              4                 28
# S                                              0                  0
# All                                            8                 58
#
# job_title     BI Analyst  BI Data Analyst  BI Data Engineer  ...  \
# company_size                                                 ...
# L                      1                3                 0  ...
# M                      4                2                 1  ...
# S                      0                1                 0  ...
# All                    5                6                 1  ...
#
# job_title     NLP Engineer  Principal Data Analyst  Principal Data Engineer  \
# company_size
# L                        0                       0                        1
# M                        4                       1                        1
# S                        0                       1                        0
# All                      4                       2                        2
#
# job_title     Principal Data Scientist  Principal Machine Learning Engineer  \
# company_size
# L                                    3                                    1
# M                                    0                                    0
# S                                    0                                    0
# All                                  3                                    1
#
# job_title     Product Data Analyst  Research Engineer  Research Scientist  \
# company_size
# L                                0                  0                   6
# M                                2                 31                  56
# S                                0                  0                   1
# All                              2                 31                  63
#
# job_title     Staff Data Analyst   All
# company_size
# L                              0   276
# M                              1  2784
# S                              0    49
# All                            1  3109
#
# [4 rows x 73 columns]

# %%
# Compute the correlation matrix
corr_matrix = df_US.corr()

# Apply a gradient color scheme to the correlation matrix
styled_corr_matrix = corr_matrix.style.background_gradient(cmap='RdBu')

# Display the styled correlation matrix
styled_corr_matrix
# Out:
# <style type="text/css">
# #T_81f43_row0_col0, #T_81f43_row1_col1, #T_81f43_row2_col2, #T_81f43_row3_col3, #T_81f43_row4_col4 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_81f43_row0_col1 {
#   background-color: #f3a481;
#   color: #000000;
# }
# #T_81f43_row0_col2, #T_81f43_row1_col4, #T_81f43_row2_col0, #T_81f43_row2_col3, #T_81f43_row4_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_81f43_row0_col3 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_81f43_row0_col4 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_81f43_row1_col0 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_81f43_row1_col2 {
#   background-color: #d05548;
#   color: #f1f1f1;
# }
# #T_81f43_row1_col3, #T_81f43_row2_col4 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_81f43_row2_col1 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_81f43_row3_col0 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_81f43_row3_col1 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_81f43_row3_col2 {
#   background-color: #bd2d35;
#   color: #f1f1f1;
# }
# #T_81f43_row3_col4 {
#   background-color: #e48066;
#   color: #f1f1f1;
# }
# #T_81f43_row4_col0 {
#   background-color: #de735c;
#   color: #f1f1f1;
# }
# #T_81f43_row4_col2 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_81f43_row4_col3 {
#   background-color: #b72230;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81f43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81f43_level0_col0" class="col_heading level0 col0" >work_year</th>
#       <th id="T_81f43_level0_col1" class="col_heading level0 col1" >salary_in_usd</th>
#       <th id="T_81f43_level0_col2" class="col_heading level0 col2" >remote_ratio</th>
#       <th id="T_81f43_level0_col3" class="col_heading level0 col3" >employee_at_job_location</th>
#       <th id="T_81f43_level0_col4" class="col_heading level0 col4" >job_title_cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81f43_level0_row0" class="row_heading level0 row0" >work_year</th>
#       <td id="T_81f43_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_81f43_row0_col1" class="data row0 col1" >0.103064</td>
#       <td id="T_81f43_row0_col2" class="data row0 col2" >-0.254189</td>
#       <td id="T_81f43_row0_col3" class="data row0 col3" >0.164965</td>
#       <td id="T_81f43_row0_col4" class="data row0 col4" >0.033961</td>
#     </tr>
#     <tr>
#       <th id="T_81f43_level0_row1" class="row_heading level0 row1" >salary_in_usd</th>
#       <td id="T_81f43_row1_col0" class="data row1 col0" >0.103064</td>
#       <td id="T_81f43_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_81f43_row1_col2" class="data row1 col2" >-0.020708</td>
#       <td id="T_81f43_row1_col3" class="data row1 col3" >0.127436</td>
#       <td id="T_81f43_row1_col4" class="data row1 col4" >-0.280347</td>
#     </tr>
#     <tr>
#       <th id="T_81f43_level0_row2" class="row_heading level0 row2" >remote_ratio</th>
#       <td id="T_81f43_row2_col0" class="data row2 col0" >-0.254189</td>
#       <td id="T_81f43_row2_col1" class="data row2 col1" >-0.020708</td>
#       <td id="T_81f43_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_81f43_row2_col3" class="data row2 col3" >-0.089008</td>
#       <td id="T_81f43_row2_col4" class="data row2 col4" >-0.029727</td>
#     </tr>
#     <tr>
#       <th id="T_81f43_level0_row3" class="row_heading level0 row3" >employee_at_job_location</th>
#       <td id="T_81f43_row3_col0" class="data row3 col0" >0.164965</td>
#       <td id="T_81f43_row3_col1" class="data row3 col1" >0.127436</td>
#       <td id="T_81f43_row3_col2" class="data row3 col2" >-0.089008</td>
#       <td id="T_81f43_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_81f43_row3_col4" class="data row3 col4" >0.037680</td>
#     </tr>
#     <tr>
#       <th id="T_81f43_level0_row4" class="row_heading level0 row4" >job_title_cluster</th>
#       <td id="T_81f43_row4_col0" class="data row4 col0" >0.033961</td>
#       <td id="T_81f43_row4_col1" class="data row4 col1" >-0.280347</td>
#       <td id="T_81f43_row4_col2" class="data row4 col2" >-0.029727</td>
#       <td id="T_81f43_row4_col3" class="data row4 col3" >0.037680</td>
#       <td id="T_81f43_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
